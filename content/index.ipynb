# %% [markdown]
# # Numerical Methods for Elliptic Problems

# %% [markdown]
# ## Materials
#
# - [Lecture notes (PDF)](script/numerical_methods.pdf)
# - [Local NGSolve installation (PDF)](getting-started/ngsolve-installation.pdf)
# - [NGSolve and WebGUI test](notebooks/00_ngsolve_test.ipynb)
# - [Lecture 1: Motivation examples from Chapter 1](notebooks/VO_2026_10_07/index.ipynb)

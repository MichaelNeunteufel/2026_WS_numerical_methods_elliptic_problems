# %% [markdown]
# # Lecture 1: Why elliptic problems?
#
# - [01 - Mass and heat transfer](01_mass_and_heat_transfer.ipynb)
# - [02 - Minimal surfaces and membranes](02_minimal_surface_and_membrane.ipynb)
# - [03 - Biharmonic plate](03_biharmonic_plate.ipynb)
# - [04 - Linear elasticity](04_linear_elasticity.ipynb)
# - [05 - Incompressible flow](05_incompressible_flow.ipynb)
# - [06 - Magneto-quasistatics](06_magneto_quasistatics.ipynb)
